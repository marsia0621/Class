# %% [markdown]
# Y=ax+b <--> y= f(x)
#
# 입력이 하나, 출력도 하나 --> 가장 간단한 형태를 취하기 때문에 다루기도 쉽다.
#
# y=a1x1+a2x2+a3x3+…..
#
# x에 제곱이 붙어도 함수임 (y = ax^2+bx+c…)
#
# Dense:  그림에서 선을 (a1,a2,,, 값을) 그려줌 = fully connected
#
# CNN = convolutional neural network
#
# 선 = edge / 점 = node
#
# 모든 graph는 node와 edge로 이루어진다.
#
#
# Cf. Linear algebra = 행렬
#
# 구조적으로 3단계 그래프는 제한을 걸어 놓음
#
# 각 Layer (node끼리의 bunch)는 adjacent해야 connected // adjacent 하지 않으면 불허
#
# edge에는 화살표가 있다 = 즉 방향성이 있다. 한 node에서 다른 node로 가는 것이 없을 수도, 양쪽일 수도, 왼쪽일 수도….. 어떤 의미를 담고 싶으면 담으면 되지만, 보통 그래프는 무조건 왼쪽에서 오른쪽으로 화살표가 있어야 함
#
#
# a값 weight를 준다. weight = 가중치
#
# 0을 준다면, 가중치를 주지 않는 것.
#
# Data에 어떤 것이 들어갔을 때 어떤 것이 나온다 = data는 반드시 pair로 이루어져야 함.
#
#
# Input --- target : 정답값 data속에 들어있는 input과 pair된 출력값쪽에 있는 값 (출력은 계산되어져 나온 값)
# 	data속에서 하나를 뺌. 입력을 넣고 계산을 함. 훈련이 되어 있기 때문에 나옴. 그러나 target값과 차이가 있다. 즉 계산되어진 출력값과
#
# target값 사이의 차이가 있다. 훈련이 잘 되어 있으면 그 차이가 줄어든다. 이 차이 = error.
#
# Data 잘 만들고, 훈련 잘하고, graph를 잘 만들어야 함.
#
# Hidden layer = 중간에 들어가는 layer.
#
# 입력과 출력 그 사이에 숨어 있음.
#
# 각각의 hidden layer의 node의 개수를 늘리면 complexity가 올라감. =어려운 문제 잘 해석. 그러나 쓸데없이 높일 필요는 x..
#
#
# Linear  더하기와 곱하기만 한다.
#
# 즉 y = ax+b는 linear.
#
# 어떠한 숫자를 곱하더라도 line이 아닐 순 없음.
#
#
# Sigmoid  어떤 수가 들어오더라도 0과 1사이에 수렴시켜라
#
# Continuous 값을 categorical하게 바꿔주는 것도 not linear
#
# 입력은 continuous하게 들어오더라도 …
#
# y = sig(ax+b)
#
# 입력이 숫잔데 출력은 숫자가 아닐 수 있음.
#
#
# <Boston Housing>
#     Data Description
# -	Crim: 범죄율
# -	Zn: 주거지 비율. 주거지의 반대 개념은 상업지.
# -	Indus: 도매 사업의 비율.
# -	Chas: dummy variable은 카테고리를 만들 때 쓰는 것. 바로 옆에 찰스 강이 흐르는지 아닌지. 흐르면 1, 아니면 0.
# -	Nox: 질소산화물의 비율.
# -	Rm: 방의 수
# -	Age: 1940년대 이전에 지어진 집의 비율
# -	Dis: 보스턴 고용 센터와의 거리의 가중평균.
# -	Rad: 고속도로 접근성.
# -	Tax: 집 보유세
# -	Ptratio: 학생-선생님 비율
# -	Black: 흑인 비율
# -	Istat: 모집단의 하위 계층의 비율
# -	Medv: 집값  출력(y)
# 	입력(x)이 총 13개, 출력(y)이 총 1개로 14개의 Column.
#
# Q. Cifar100에서 100 x 100 인 그림이 있을 때, 숫자는 몇 개?
# 	흑백이면 10000, 컬러면 30000 (RGB니까)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path = 'boston_housing.npz')

# %%
model = Sequential()
model.add(Dense(1, input_shape=[13]))
model.compile(optimizer='rmsprop', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 14
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=1000)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1000
# 404/404 [==============================] - 1s 3ms/sample - loss: 89579.8433
# Epoch 2/1000
# 404/404 [==============================] - 0s 133us/sample - loss: 81076.0098
# Epoch 3/1000
# 404/404 [==============================] - 0s 99us/sample - loss: 74380.9375
# Epoch 4/1000
# 404/404 [==============================] - 0s 105us/sample - loss: 68199.3085
# Epoch 5/1000
# 404/404 [==============================] - 0s 82us/sample - loss: 62319.7457
# Epoch 6/1000
# 404/404 [==============================] - 0s 127us/sample - loss: 56706.4572
# Epoch 7/1000
# 404/404 [==============================] - 0s 123us/sample - loss: 51403.6443
# Epoch 8/1000
# ...

# %%
model.evaluate(x_train, y_train)
# Out:
# 404/404 [==============================] - 0s 595us/sample - loss: 28.2009
# 28.20087451745968

# %%
model.predict(np.array([0, 1, 50, 1, 0, 5, .5, 10, 1000, 100, 10, 100, 1]).reshape(1,13))
# Out:
# array([[198.80812]], dtype=float32)
